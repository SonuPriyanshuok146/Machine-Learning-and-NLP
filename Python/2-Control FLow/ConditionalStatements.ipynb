# %% [markdown]
# ### Conditional Statement

# %%
## if Statement
age = 20

if age >= 18:
    print("you are allowed to vote in the Election.")
# Out:
# you are allowed to vote in the Election.

# %%
age >= 18
# Out:
# True

# %%
## else
## the else statement execute the block of code if the condition in the if statement is false

age = 16
if age >= 18:
    print("You are eligible for voting.")
else:
    print("You are a minor.")
# Out:
# You are a minor.

# %%
## elif
## the elif statement allows to check the multiple conditions. it stand for "else if"
age = 20

if age < 13:
    print("You are a child.")
elif age < 18:
    print("You are teenager")
else:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
## Nested conditional statements

## you can place one or more inside another if, elif, or else statements.

num=int(input("Enter the number: "))
if num>0:
    print("The  number is positive.")
    if num%2==0:
        print("The Number is even")
    else:
        print("The Number is odd")
else:
    print("The number is Zero or negative.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 ## Nested conditional statements
#       2
#       3 ## you can place one or more inside another if, elif, or else statements.
# ----> 5 num=int(input("Enter the number: "))
#       6 if num>0:
#       7     print("The  number is positive.")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
## Practicl examples
## Determine if a year is a leap year using nested condition
year = int(input("Enter the year:"))

if year % 4 == 0:
    if year%100 == 0:
        if year%400 == 0:
            print(year,"is a leap year.")
        else:
            print(year,"is not a leap year.")
    else:
        print(year,"is not a leap year.")
else:
    print(year,"is not a leap year.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 ## Practicl examples
#       2 ## Determine if a year is a leap year using nested condition
# ----> 3 year = int(input("Enter the year:"))
#       5 if year % 4 == 0:
#       6     if year%100 == 0:
#
# ValueError: invalid literal for int() with base 10: ''
