# %%
## Integer Examples
age=35
type(age)
# Out:
# int

# %%
## Floating point datatype
height = 5.4
print(height)
print(type(height))
# Out:
# 5.4
# <class 'float'>

# %%
## String datatye example
name = "Sonu"
print(name)
print(type(name))
# Out:
# Sonu
# <class 'str'>

# %%
## Boolean datatype
is_true = True
type(is_true)
# Out:
# bool

# %%
a = 10
b = 10

type(a == b)
# Out:
# bool

# %%
## Common Errors
result = "Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 ## Common Errors
# ----> 2 result = "Hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "Hello" + str(5)
print(result)
# Out:
# Hello5
